# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from scipy import stats
from sklearn import metrics
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Download dataset
! wget https://www.utwente.nl/en/eemcs/ps/dataset-folder/sensors-activity-recognition-dataset-shoaib.rar -P ../data/

# Extract dataset using unrar
# !pip install unrar
# !unrar e ../data/sensors-activity-recognition-dataset-shoaib.rar ../data/
# Out:
# --2022-05-05 04:25:20--  https://www.utwente.nl/en/eemcs/ps/dataset-folder/sensors-activity-recognition-dataset-shoaib.rar
# Resolving www.utwente.nl (www.utwente.nl)... 130.89.3.249, 2001:67c:2564:a102::1:1
# Connecting to www.utwente.nl (www.utwente.nl)|130.89.3.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100080442 (95M) [application/x-rar-compressed]
# Saving to: ‘../data/sensors-activity-recognition-dataset-shoaib.rar’
#
# sensors-activity-re 100%[===================>]  95.44M  14.2MB/s    in 8.2s
#
# 2022-05-05 04:25:29 (11.6 MB/s) - ‘../data/sensors-activity-recognition-dataset-shoaib.rar’ saved [100080442/100080442]
#
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from ../data/sensors-activity-recognition-dataset-shoaib.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
df = pd.DataFrame()
for i in range(10):
    df_tmp = pd.read_csv('../data/Participant_' + str(i+1) + '.csv', header=1)
    df = pd.concat([df, df_tmp])

df.head()
# Out:
#      time_stamp       Ax      Ay       Az       Lx      Ly       Lz       Gx  \
# 0  1.390000e+12 -1.81150 -14.873 -1.34840 -1.26910 -5.1057 -0.66445 -0.53206
# 1  1.390000e+12  0.24517 -14.070 -0.84446  0.70147 -4.2969 -0.17199 -0.25229
# 2  1.390000e+12 -0.57205 -14.628 -1.75700 -0.21760 -4.8531 -1.05650 -1.04920
# 3  1.390000e+12 -0.69464 -12.939 -3.09180 -0.32273 -3.1786 -2.21970 -2.37200
# 4  1.390000e+12  0.87170 -12.000 -1.56630  1.13740 -2.2390 -0.65476 -2.79010
#
#         Gy       Gz  ...    Lx.4     Ly.4      Lz.4     Gx.4     Gy.4  \
# 0 -3.18690  0.23976  ... -5.3574 -0.95749  0.318860  0.52565 -0.18815
# 1 -1.79660  0.40745  ... -4.5352 -0.67629  0.081656  0.43616  0.16371
# 2  0.29138  0.29230  ... -4.0408 -0.55974 -0.523690  0.32284  0.43127
# 3  1.00820  0.34972  ... -3.5908  0.15795 -1.880200  0.20403  0.72846
# 4  0.65485  0.22724  ... -1.9450  0.85796 -2.995300  0.09896  0.94379
#
#        Gz.4   Mx.4  My.4  Mz.4  Unnamed: 69
# 0  0.285880 -22.20  6.48  4.56      walking
# 1  0.198230 -21.90  7.14  5.34      walking
# 2  0.211970 -21.60  7.50  5.64      walking
# 3  0.164930 -21.12  8.40  6.12      walking
# 4  0.064752 -20.94  8.70  6.30      walking
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (630000, 70)

# %%
split_point = int(len(df) * 0.8)
train_data = df.iloc[:split_point, :]
test_data = df.iloc[split_point:, :]

print("Number of train samples: ", len(train_data))
print("Number of test samples: ", len(test_data))
# Out:
# Number of train samples:  504000
# Number of test samples:  126000

# %%
def concat(data):
    
    # Select left pocket data
    left_pocket = data.iloc[:,1:10]
    
    #Square root of sum of squares of accelerometer, linear acceleration and gyroscope data
    left_pocket["MA"] = np.sqrt(np.square(left_pocket['Ax']) + np.square(left_pocket['Ay']) + np.square(left_pocket['Az']))
    left_pocket["ML"] = np.sqrt(np.square(left_pocket['Lx']) + np.square(left_pocket['Ly']) + np.square(left_pocket['Lz']))
    left_pocket["MG"] = np.sqrt(np.square(left_pocket['Gx']) + np.square(left_pocket['Gy']) + np.square(left_pocket['Gz']))
    

    # Select right pocket data
    right_pocket = data.iloc[:,15:24]
    right_pocket.columns=['Ax', 'Ay', 'Az', 'Lx', 'Ly', 'Lz', 'Gx', 'Gy', 'Gz']
    
    #Square root of sum of squares of accelerometer, linear acceleration and gyroscope data
    right_pocket["MA"] = np.sqrt(np.square(right_pocket['Ax']) + np.square(right_pocket['Ay']) + np.square(right_pocket['Az']))
    right_pocket["ML"] = np.sqrt(np.square(right_pocket['Lx']) + np.square(right_pocket['Ly']) + np.square(right_pocket['Lz']))
    right_pocket["MG"] = np.sqrt(np.square(right_pocket['Gx']) + np.square(right_pocket['Gy']) + np.square(right_pocket['Gz']))

    
    # Extract labels 
    labels = data.iloc[:, 69] 
    labels = labels.to_frame()
    labels.columns=['Activity_Label']
    labels = pd.concat([labels]*2, ignore_index=True)
    #replace typo 'upsatirs' with upstairs! 
    labels.loc[(labels['Activity_Label'] == 'upsatirs')] = 'upstairs'
    
    #Concatenate left pocket and right pocket data into a single data frame (we only use left pocket and right pocket data)
    frames = [left_pocket, right_pocket]
    df = pd.concat(frames)
   
    return df, labels

# Generate input data and labels
train_X, train_y = concat(train_data)
test_X, test_y = concat(test_data)
train_X.head()
# Out:
#         Ax      Ay       Az       Lx      Ly       Lz       Gx       Gy  \
# 0 -1.81150 -14.873 -1.34840 -1.26910 -5.1057 -0.66445 -0.53206 -3.18690
# 1  0.24517 -14.070 -0.84446  0.70147 -4.2969 -0.17199 -0.25229 -1.79660
# 2 -0.57205 -14.628 -1.75700 -0.21760 -4.8531 -1.05650 -1.04920  0.29138
# 3 -0.69464 -12.939 -3.09180 -0.32273 -3.1786 -2.21970 -2.37200  1.00820
# 4  0.87170 -12.000 -1.56630  1.13740 -2.2390 -0.65476 -2.79010  0.65485
#
#         Gz         MA        ML        MG
# 0  0.23976  15.043465  5.302856  3.239893
# 1  0.40745  14.097451  4.357177  1.859419
# 2  0.29230  14.744242  4.971531  1.127458
# 3  0.34972  13.321392  3.890337  2.600991
# 4  0.22724  12.133143  2.595286  2.874913

# %%
train_y.head()
# Out:
#   Activity_Label
# 0        walking
# 1        walking
# 2        walking
# 3        walking
# 4        walking

# %%
N_TIME_STEPS = 100 #sliding window length
STEP = 50 #Sliding window step size
N_FEATURES = 12 

def generate_sequence(x, y, n_time_steps, step):
    
    segments = []
    labels = []
    for i in range(0, len(x) - n_time_steps, step):
        ax = x['Ax'].values[i: i + n_time_steps]
        ay = x['Ay'].values[i: i + n_time_steps]
        az = x['Az'].values[i: i + n_time_steps]

        lx = x['Lx'].values[i: i + n_time_steps]
        ly = x['Ly'].values[i: i + n_time_steps]
        lz = x['Lz'].values[i: i + n_time_steps]
        
        gx = x['Gx'].values[i: i + n_time_steps]
        gy = x['Gy'].values[i: i + n_time_steps]
        gz = x['Gz'].values[i: i + n_time_steps]

        MA = x['MA'].values[i: i + n_time_steps]
        ML = x['ML'].values[i: i + n_time_steps]
        MG = x['MG'].values[i: i + n_time_steps]
       
        label = stats.mode(y['Activity_Label'][i: i + n_time_steps])[0][0]
        segments.append([ax, ay, az, lx, ly, lz, gx, gy, gz, MA, ML, MG])
        labels.append(label)
        
    return segments, labels

train_X, train_y = generate_sequence(train_X, train_y, N_TIME_STEPS, STEP)
test_X, test_y = generate_sequence(test_X, test_y, N_TIME_STEPS, STEP)

# %%
# reshape input segments and one-hot encode labels
def reshape_segments(x, y, n_time_steps, n_features):
    
    x_reshaped = np.asarray(x, dtype= np.float32).reshape(-1, n_time_steps, n_features)
    y_reshaped = np.asarray(pd.get_dummies(y), dtype = np.float32)
    return x_reshaped, y_reshaped

X_train, y_train = reshape_segments(train_X, train_y, N_TIME_STEPS, N_FEATURES)
X_test, y_test = reshape_segments(test_X, test_y, N_TIME_STEPS, N_FEATURES)

# %%
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Flatten
from tensorflow.keras import optimizers

N_CLASSES = 7
N_HIDDEN_UNITS = 32
L2 = 0.000001

model = Sequential([
    LSTM(N_HIDDEN_UNITS, return_sequences=True, input_shape=(N_TIME_STEPS, N_FEATURES), 
         kernel_initializer='orthogonal', kernel_regularizer=l2(L2), recurrent_regularizer=l2(L2),
         bias_regularizer=l2(L2), name="LSTM_1"),
    Flatten(name='Flatten'),
    Dense(N_HIDDEN_UNITS, activation='relu', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_1"),
    Dense(N_CLASSES, activation='softmax', kernel_regularizer=l2(L2), bias_regularizer=l2(L2), name="Dense_2")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_1 (LSTM)               (None, 100, 32)           5760
#
#  Flatten (Flatten)           (None, 3200)              0
#
#  Dense_1 (Dense)             (None, 32)                102432
#
#  Dense_2 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 108,423
# Trainable params: 108,423
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = optimizers.RMSprop(lr=0.0001)

model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
BATCH_SIZE = 1024
N_EPOCHS = 40

model.fit(X_train, y_train,
          batch_size=BATCH_SIZE, epochs=N_EPOCHS,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 20/20 [==============================] - 12s 83ms/step - loss: 1.5398 - accuracy: 0.4960 - val_loss: 1.2894 - val_accuracy: 0.6334
# Epoch 2/40
# 20/20 [==============================] - 0s 24ms/step - loss: 1.0998 - accuracy: 0.7532 - val_loss: 0.9864 - val_accuracy: 0.7692
# Epoch 3/40
# 20/20 [==============================] - 0s 21ms/step - loss: 0.8305 - accuracy: 0.8522 - val_loss: 0.7641 - val_accuracy: 0.8535
# Epoch 4/40
# 20/20 [==============================] - 0s 24ms/step - loss: 0.6239 - accuracy: 0.9058 - val_loss: 0.5914 - val_accuracy: 0.9043
# Epoch 5/40
# 20/20 [==============================] - 0s 21ms/step - loss: 0.4711 - accuracy: 0.9382 - val_loss: 0.4622 - val_accuracy: 0.9369
# Epoch 6/40
# 20/20 [==============================] - 0s 22ms/step - loss: 0.3624 - accuracy: 0.9463 - val_loss: 0.3672 - val_accuracy: 0.9436
# Epoch 7/40
# 20/20 [==============================] - 0s 22ms/step - loss: 0.2850 - accuracy: 0.9524 - val_loss: 0.3018 - val_accuracy: 0.9470
# Epoch 8/40
# 20/20 [==============================] - 0s 21ms/step - loss: 0.2308 - accuracy: 0.9571 - val_loss: 0.2482 - val_accuracy: 0.9593
# Epoch 9/40
# 20/20 [==============================] - 0s 22ms/step - loss: 0.1923 - accuracy: 0.9617 - val_loss: 0.2172 - val_accuracy: 0.9587
# Epoch 10/40
# 20/20 [==============================] - 0s 19ms/step - loss: 0.1645 - accuracy: 0.9666 - val_loss: 0.1883 - val_accuracy: 0.9647
# Epoch 11/40
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1430 - accuracy: 0.9706 - val_loss: 0.1645 - val_accuracy: 0.9714
# Epoch 12/40
# 20/20 [==============================] - 0s 21ms/step - loss: 0.1260 - accuracy: 0.9731 - val_loss: 0.1503 - val_accuracy: 0.9694
# Epoch 13/40
# 20/20 [==============================] - 0s 20ms/step - loss: 0.1129 - accuracy: 0.9751 - val_loss: 0.1355 - val_accuracy: 0.9730
# Epoch 14/40
# 20/20 [==============================] - 0s 23ms/step - loss: 0.1019 - accuracy: 0.9772 - val_loss: 0.1279 - val_accuracy: 0.9730
# Epoch 15/40
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0929 - accuracy: 0.9790 - val_loss: 0.1213 - val_accuracy: 0.9748
# Epoch 16/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0848 - accuracy: 0.9809 - val_loss: 0.1108 - val_accuracy: 0.9772
# Epoch 17/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0786 - accuracy: 0.9829 - val_loss: 0.1080 - val_accuracy: 0.9788
# Epoch 18/40
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0724 - accuracy: 0.9841 - val_loss: 0.0985 - val_accuracy: 0.9802
# Epoch 19/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0674 - accuracy: 0.9849 - val_loss: 0.0963 - val_accuracy: 0.9802
# Epoch 20/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0628 - accuracy: 0.9859 - val_loss: 0.0985 - val_accuracy: 0.9778
# Epoch 21/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0592 - accuracy: 0.9874 - val_loss: 0.0909 - val_accuracy: 0.9811
# Epoch 22/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0556 - accuracy: 0.9879 - val_loss: 0.0884 - val_accuracy: 0.9813
# Epoch 23/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0525 - accuracy: 0.9884 - val_loss: 0.0858 - val_accuracy: 0.9807
# Epoch 24/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0497 - accuracy: 0.9890 - val_loss: 0.0833 - val_accuracy: 0.9809
# Epoch 25/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0469 - accuracy: 0.9896 - val_loss: 0.0784 - val_accuracy: 0.9823
# Epoch 26/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0446 - accuracy: 0.9897 - val_loss: 0.0837 - val_accuracy: 0.9803
# Epoch 27/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0423 - accuracy: 0.9904 - val_loss: 0.0767 - val_accuracy: 0.9815
# Epoch 28/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0401 - accuracy: 0.9907 - val_loss: 0.0747 - val_accuracy: 0.9817
# Epoch 29/40
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0383 - accuracy: 0.9914 - val_loss: 0.0745 - val_accuracy: 0.9815
# Epoch 30/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0364 - accuracy: 0.9917 - val_loss: 0.0743 - val_accuracy: 0.9811
# Epoch 31/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0349 - accuracy: 0.9921 - val_loss: 0.0705 - val_accuracy: 0.9823
# Epoch 32/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0331 - accuracy: 0.9924 - val_loss: 0.0753 - val_accuracy: 0.9794
# Epoch 33/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0316 - accuracy: 0.9928 - val_loss: 0.0703 - val_accuracy: 0.9823
# Epoch 34/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0300 - accuracy: 0.9933 - val_loss: 0.0757 - val_accuracy: 0.9778
# Epoch 35/40
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0287 - accuracy: 0.9934 - val_loss: 0.0661 - val_accuracy: 0.9841
# Epoch 36/40
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0276 - accuracy: 0.9939 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 37/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0262 - accuracy: 0.9943 - val_loss: 0.0692 - val_accuracy: 0.9805
# Epoch 38/40
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0251 - accuracy: 0.9949 - val_loss: 0.0691 - val_accuracy: 0.9807
# Epoch 39/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0240 - accuracy: 0.9950 - val_loss: 0.0704 - val_accuracy: 0.9786
# Epoch 40/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0230 - accuracy: 0.9951 - val_loss: 0.0663 - val_accuracy: 0.9819

# %%
y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
confusion_matrix = metrics.confusion_matrix(y_true=y_true_labels, y_pred=y_pred_labels)

LABELS = ['Running' ,' Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']

plt.figure(figsize=(16, 14))
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show();

# %%
from keras import backend
from tensorflow.python.tools import freeze_graph
from tensorflow.python.tools import optimize_for_inference_lib

input_node_names= ["LSTM_1_input"]
output_node_name = "Dense_2/Softmax"
MODEL_NAME = "HAR"

tf.train.write_graph(backend.get_session().graph_def, 'models', \MODEL_NAME + '_graph.pbtxt')
saver = tf.train.Saver()
saver.save(backend.get_session(), 'models/' + MODEL_NAME + '.chkp')

freeze_graph.freeze_graph('models/' + MODEL_NAME + '_graph.pbtxt', None, \False, 'models/' + MODEL_NAME + '.chkp', output_node_name, \"save/restore_all", "save/Const:0", \'models/frozen_' + MODEL_NAME + '.pb', True, "")
